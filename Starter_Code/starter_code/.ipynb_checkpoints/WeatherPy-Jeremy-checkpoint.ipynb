# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\shang\anaconda3\envs\dev\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\shang\anaconda3\envs\dev\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# #For testing purposes only
# url = "http://api.openweathermap.org/data/2.5/weather?"
# city = "scarborough"
# units = "metric"
# query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
# print(query_url)
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# print(weather_json)

# %%
# weather_json['main']['temp_max']
# Out:
# 11.07

# %%
#url = # YOUR CODE HERE
url ="https://api.openweathermap.org/data/2.5/weather?"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =f"{url}appid={weather_api_key}&q={city}&units=metric"
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sayyan
# Processing Record 2 of Set 1 | meulaboh
# Processing Record 3 of Set 1 | souillac
# Processing Record 4 of Set 1 | ekhabi
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | neiafu
# Processing Record 8 of Set 1 | santa cruz
# Processing Record 9 of Set 1 | pasighat
# Processing Record 10 of Set 1 | nantucket
# Processing Record 11 of Set 1 | arraial do cabo
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | te anau
# Processing Record 15 of Set 1 | saint-ambroise
# Processing Record 16 of Set 1 | kenai
# Processing Record 17 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 1 | sijunjung
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | along
# Processing Record 23 of Set 1 | saldanha
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | upata
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | eyl
# Processing Record 28 of Set 1 | tandalti
# Processing Record 29 of Set 1 | norman wells
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | sorland
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | inirida
# Processing Record 35 of Set 1 | atambua
# Processing Record 36 of Set 1 | safaga
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 40 of Set 1 | esperance
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | abalak
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | baghdad
# Processing Record 45 of Set 1 | mandera
# Processing Record 46 of Set 1 | rush
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | la ronge
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 0 of Set 2 | atuona
# Processing Record 1 of Set 2 | kargasok
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | olga
# Processing Record 5 of Set 2 | kahului
# Processing Record 6 of Set 2 | touros
# Processing Record 7 of Set 2 | chudovo
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | karratha
# Processing Record 10 of Set 2 | sao filipe
# Processing Record 11 of Set 2 | coshocton
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | linfen
# Processing Record 14 of Set 2 | jalu
# Processing Record 15 of Set 2 | kerema
# Processing Record 16 of Set 2 | kumluca
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | vanavara
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | plettenberg bay
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | kruisfontein
# Processing Record 26 of Set 2 | balabac
# Processing Record 27 of Set 2 | san alejo
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | mancio lima
# Processing Record 30 of Set 2 | los llanos de aridane
# Processing Record 31 of Set 2 | yellowknife
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | kaeo
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | nouadhibou
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | srednekolymsk
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | emirdag
# Processing Record 47 of Set 2 | ayan
# Processing Record 48 of Set 2 | velsk
# Processing Record 49 of Set 2 | obo
# Processing Record 0 of Set 3 | vestmanna
# Processing Record 1 of Set 3 | valle del guamuez
# Processing Record 2 of Set 3 | coquimbo
# Processing Record 3 of Set 3 | barcelos
# Processing Record 4 of Set 3 | khani
# Processing Record 5 of Set 3 | gimli
# Processing Record 6 of Set 3 | honningsvag
# Processing Record 7 of Set 3 | cam ranh
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | tezu
# Processing Record 12 of Set 3 | walvis bay
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | porto santo
# Processing Record 15 of Set 3 | correntina
# Processing Record 16 of Set 3 | pacifica
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | severnyy
# Processing Record 19 of Set 3 | sladkovo
# Processing Record 20 of Set 3 | shestakovo
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | tuatapere
# Processing Record 23 of Set 3 | tokur
# Processing Record 24 of Set 3 | odlabari
# Processing Record 25 of Set 3 | kimbe
# Processing Record 26 of Set 3 | prince rupert
# Processing Record 27 of Set 3 | matara
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | burnie
# Processing Record 30 of Set 3 | krasnoselkup
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | kamaishi
# Processing Record 33 of Set 3 | manokwari
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | sheridan
# Processing Record 36 of Set 3 | northam
# Processing Record 37 of Set 3 | sestri levante
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | zhezkazgan
# Processing Record 40 of Set 3 | griffith
# Processing Record 41 of Set 3 | portland
# Processing Record 42 of Set 3 | nazira
# Processing Record 43 of Set 3 | progreso
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | midland
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | pemangkat
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 0 of Set 4 | tuktoyaktuk
# Processing Record 1 of Set 4 | khuzhir
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | tsaratanana
# Processing Record 4 of Set 4 | parit buntar
# Processing Record 5 of Set 4 | palmer
# Processing Record 6 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 4 | kiruna
# Processing Record 8 of Set 4 | padang
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | kampot
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | ancud
# Processing Record 13 of Set 4 | chapleau
# Processing Record 14 of Set 4 | varkaus
# Processing Record 15 of Set 4 | knysna
# Processing Record 16 of Set 4 | enumclaw
# Processing Record 17 of Set 4 | saint anthony
# Processing Record 18 of Set 4 | diamantina
# Processing Record 19 of Set 4 | seddon
# Processing Record 20 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 21 of Set 4 | buala
# Processing Record 22 of Set 4 | necochea
# Processing Record 23 of Set 4 | alofi
# Processing Record 24 of Set 4 | tecoanapa
# Processing Record 25 of Set 4 | kropotkin
# Processing Record 26 of Set 4 | christchurch
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | olafsvik
# Processing Record 29 of Set 4 | tyrma
# Processing Record 30 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 4 | batagay-alyta
# Processing Record 32 of Set 4 | dingle
# Processing Record 33 of Set 4 | pitimbu
# Processing Record 34 of Set 4 | corowa
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | maua
# Processing Record 37 of Set 4 | dudinka
# Processing Record 38 of Set 4 | kondopoga
# Processing Record 39 of Set 4 | valdepenas
# Processing Record 40 of Set 4 | xining
# Processing Record 41 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 4 | la romana
# Processing Record 43 of Set 4 | dikson
# Processing Record 44 of Set 4 | nanortalik
# Processing Record 45 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 4 | chara
# Processing Record 47 of Set 4 | moundou
# Processing Record 48 of Set 4 | thompson
# Processing Record 49 of Set 4 | buritizeiro
# Processing Record 0 of Set 5 | dawlatabad
# Processing Record 1 of Set 5 | port-gentil
# Processing Record 2 of Set 5 | rondonopolis
# Processing Record 3 of Set 5 | vermillion
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | berezovka
# Processing Record 6 of Set 5 | harper
# Processing Record 7 of Set 5 | ibotirama
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 5 | hornepayne
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | morant bay
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | maxixe
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | kununurra
# Processing Record 17 of Set 5 | half moon bay
# Processing Record 18 of Set 5 | yerofey pavlovich
# Processing Record 19 of Set 5 | ixtapa
# Processing Record 20 of Set 5 | astana
# Processing Record 21 of Set 5 | uhlove
# Processing Record 22 of Set 5 | matagami
# Processing Record 23 of Set 5 | maceio
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | clyde river
# Processing Record 26 of Set 5 | sept-iles
# Processing Record 27 of Set 5 | bengkulu
# Processing Record 28 of Set 5 | pringsewu
# Processing Record 29 of Set 5 | puerto ayora
# Processing Record 30 of Set 5 | broome
# Processing Record 31 of Set 5 | muravlenko
# Processing Record 32 of Set 5 | coihaique
# Processing Record 33 of Set 5 | high level
# Processing Record 34 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 5 | cabo san lucas
# Processing Record 36 of Set 5 | kapaa
# Processing Record 37 of Set 5 | egvekinot
# Processing Record 38 of Set 5 | marrakesh
# Processing Record 39 of Set 5 | waingapu
# Processing Record 40 of Set 5 | college
# Processing Record 41 of Set 5 | manta
# Processing Record 42 of Set 5 | bowmore
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | olinda
# Processing Record 45 of Set 5 | kon tum
# Processing Record 46 of Set 5 | ribeira brava
# Processing Record 47 of Set 5 | encruzilhada
# Processing Record 48 of Set 5 | hefei
# Processing Record 49 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 0 of Set 6 | novo aripuana
# Processing Record 1 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | omaruru
# Processing Record 4 of Set 6 | bastia
# Processing Record 5 of Set 6 | waipawa
# Processing Record 6 of Set 6 | port lincoln
# Processing Record 7 of Set 6 | nikolskoye
# Processing Record 8 of Set 6 | centralia
# Processing Record 9 of Set 6 | wakkanai
# Processing Record 10 of Set 6 | sabha
# Processing Record 11 of Set 6 | thinadhoo
# Processing Record 12 of Set 6 | le port
# Processing Record 13 of Set 6 | ullal
# Processing Record 14 of Set 6 | asau
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | ishigaki
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | tongzi
# Processing Record 19 of Set 6 | kokopo
# Processing Record 20 of Set 6 | gushikawa
# Processing Record 21 of Set 6 | mecca
# Processing Record 22 of Set 6 | pingzhuang
# Processing Record 23 of Set 6 | mareeba
# Processing Record 24 of Set 6 | santa cruz do sul
# Processing Record 25 of Set 6 | shenjiamen
# Processing Record 26 of Set 6 | maple creek
# Processing Record 27 of Set 6 | zemio
# Processing Record 28 of Set 6 | suamico
# Processing Record 29 of Set 6 | ribeira grande
# Processing Record 30 of Set 6 | ocampo
# Processing Record 31 of Set 6 | whitehorse
# Processing Record 32 of Set 6 | duvan
# Processing Record 33 of Set 6 | burgos
# Processing Record 34 of Set 6 | broken hill
# Processing Record 35 of Set 6 | mastic beach
# Processing Record 36 of Set 6 | tura
# Processing Record 37 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | sitka
# Processing Record 41 of Set 6 | nhulunbuy
# Processing Record 42 of Set 6 | kavaratti
# Processing Record 43 of Set 6 | partenit
# Processing Record 44 of Set 6 | maniitsoq
# Processing Record 45 of Set 6 | cassilandia
# Processing Record 46 of Set 6 | oranjemund
# Processing Record 47 of Set 6 | tazovskiy
# Processing Record 48 of Set 6 | parabel
# Processing Record 49 of Set 6 | katsuura
# Processing Record 0 of Set 7 | chibombo
# Processing Record 1 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 7 | deputatskiy
# Processing Record 3 of Set 7 | rovaniemi
# Processing Record 4 of Set 7 | novocherkassk
# Processing Record 5 of Set 7 | praia da vitoria
# Processing Record 6 of Set 7 | la malbaie
# Processing Record 7 of Set 7 | vanimo
# Processing Record 8 of Set 7 | saiha
# Processing Record 9 of Set 7 | enkhuizen
# Processing Record 10 of Set 7 | victoria
# Processing Record 11 of Set 7 | moose factory
# Processing Record 12 of Set 7 | port hedland
# Processing Record 13 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 7 | shingu
# Processing Record 15 of Set 7 | xuanhua
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 7 | ola
# Processing Record 20 of Set 7 | palu
# Processing Record 21 of Set 7 | nkan
# Processing Record 22 of Set 7 | port hawkesbury
# Processing Record 23 of Set 7 | abnub
# Processing Record 24 of Set 7 | eureka
# Processing Record 25 of Set 7 | seinajoki
# Processing Record 26 of Set 7 | veraval
# Processing Record 27 of Set 7 | alappuzha
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | antofagasta
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | cap-aux-meules
# Processing Record 32 of Set 7 | ozernovskiy
# Processing Record 33 of Set 7 | havelock
# Processing Record 34 of Set 7 | bathurst
# Processing Record 35 of Set 7 | bambous virieux
# Processing Record 36 of Set 7 | xam nua
# Processing Record 37 of Set 7 | limbang
# Processing Record 38 of Set 7 | miri
# Processing Record 39 of Set 7 | storforshei
# Processing Record 40 of Set 7 | palasa
# Processing Record 41 of Set 7 | burica
# City not found. Skipping...
# Processing Record 42 of Set 7 | anloga
# Processing Record 43 of Set 7 | normandin
# Processing Record 44 of Set 7 | marsh harbour
# Processing Record 45 of Set 7 | barahona
# Processing Record 46 of Set 7 | kautokeino
# Processing Record 47 of Set 7 | koumac
# Processing Record 48 of Set 7 | shimoda
# Processing Record 49 of Set 7 | mantua
# Processing Record 0 of Set 8 | ingersoll
# Processing Record 1 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 8 | qandala
# Processing Record 3 of Set 8 | ntungamo
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | ostrovnoy
# Processing Record 6 of Set 8 | najran
# Processing Record 7 of Set 8 | umea
# Processing Record 8 of Set 8 | kaitangata
# Processing Record 9 of Set 8 | sola
# Processing Record 10 of Set 8 | fort nelson
# Processing Record 11 of Set 8 | geraldton
# Processing Record 12 of Set 8 | bull savanna
# Processing Record 13 of Set 8 | zaysan
# Processing Record 14 of Set 8 | fortuna
# Processing Record 15 of Set 8 | otjiwarongo
# Processing Record 16 of Set 8 | cayenne
# Processing Record 17 of Set 8 | chilca
# Processing Record 18 of Set 8 | lata
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | cooma
# Processing Record 21 of Set 8 | okhotsk
# Processing Record 22 of Set 8 | filadelfia
# Processing Record 23 of Set 8 | bilma
# Processing Record 24 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 8 | havoysund
# Processing Record 26 of Set 8 | zlobin
# Processing Record 27 of Set 8 | aktash
# Processing Record 28 of Set 8 | bethel
# Processing Record 29 of Set 8 | tual
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | devils lake
# Processing Record 32 of Set 8 | chipiona
# Processing Record 33 of Set 8 | aykhal
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | thunder bay
# Processing Record 36 of Set 8 | koster
# Processing Record 37 of Set 8 | sisimiut
# Processing Record 38 of Set 8 | bud
# Processing Record 39 of Set 8 | vostok
# Processing Record 40 of Set 8 | nome
# Processing Record 41 of Set 8 | yenagoa
# Processing Record 42 of Set 8 | santa isabel do rio negro
# Processing Record 43 of Set 8 | sao joao da barra
# Processing Record 44 of Set 8 | san felipe
# Processing Record 45 of Set 8 | codrington
# Processing Record 46 of Set 8 | collingwood
# Processing Record 47 of Set 8 | batsfjord
# Processing Record 48 of Set 8 | garowe
# Processing Record 49 of Set 8 | dutlwe
# Processing Record 0 of Set 9 | aklavik
# Processing Record 1 of Set 9 | mago
# Processing Record 2 of Set 9 | catuday
# Processing Record 3 of Set 9 | mersing
# Processing Record 4 of Set 9 | yumen
# Processing Record 5 of Set 9 | umm lajj
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | mandalgovi
# Processing Record 8 of Set 9 | margate
# Processing Record 9 of Set 9 | great yarmouth
# Processing Record 10 of Set 9 | kindu
# Processing Record 11 of Set 9 | velizh
# Processing Record 12 of Set 9 | ahuimanu
# Processing Record 13 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 14 of Set 9 | puerto escondido
# Processing Record 15 of Set 9 | kalmunai
# Processing Record 16 of Set 9 | komsomolskiy
# Processing Record 17 of Set 9 | kasongo-lunda
# Processing Record 18 of Set 9 | barro
# Processing Record 19 of Set 9 | ubinskoye
# Processing Record 20 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 21 of Set 9 | puerto del rosario
# Processing Record 22 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 9 | alim
# Processing Record 24 of Set 9 | dwarka
# Processing Record 25 of Set 9 | semnan
# Processing Record 26 of Set 9 | pampa
# Processing Record 27 of Set 9 | champerico
# Processing Record 28 of Set 9 | seoul
# Processing Record 29 of Set 9 | nuuk
# Processing Record 30 of Set 9 | bandar penggaram
# City not found. Skipping...
# Processing Record 31 of Set 9 | gao
# Processing Record 32 of Set 9 | beloha
# Processing Record 33 of Set 9 | kalevala
# Processing Record 34 of Set 9 | padre bernardo
# Processing Record 35 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 9 | oktyabrskoye
# Processing Record 37 of Set 9 | khandbari
# Processing Record 38 of Set 9 | washington
# Processing Record 39 of Set 9 | lazaro cardenas
# Processing Record 40 of Set 9 | fernie
# Processing Record 41 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 9 | matamoros
# Processing Record 43 of Set 9 | tateyama
# Processing Record 44 of Set 9 | mala bilozerka
# Processing Record 45 of Set 9 | caravelas
# Processing Record 46 of Set 9 | farafangana
# Processing Record 47 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 9 | luanda
# Processing Record 49 of Set 9 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 0 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 1 of Set 10 | rocha
# Processing Record 2 of Set 10 | oistins
# Processing Record 3 of Set 10 | guerrero negro
# Processing Record 4 of Set 10 | bilibino
# Processing Record 5 of Set 10 | rawson
# Processing Record 6 of Set 10 | bonthe
# Processing Record 7 of Set 10 | caucaia
# Processing Record 8 of Set 10 | port shepstone
# Processing Record 9 of Set 10 | hailun
# Processing Record 10 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 10 | samarai
# Processing Record 12 of Set 10 | lebu
# Processing Record 13 of Set 10 | hambantota
# Processing Record 14 of Set 10 | orgtrud
# Processing Record 15 of Set 10 | boyarka
# Processing Record 16 of Set 10 | berlevag
# Processing Record 17 of Set 10 | preobrazheniye
# Processing Record 18 of Set 10 | iquitos
# Processing Record 19 of Set 10 | pangai
# Processing Record 20 of Set 10 | madimba
# Processing Record 21 of Set 10 | maarianhamina
# Processing Record 22 of Set 10 | nenjiang
# Processing Record 23 of Set 10 | tehachapi
# Processing Record 24 of Set 10 | frauenfeld
# Processing Record 25 of Set 10 | saint-pierre
# Processing Record 26 of Set 10 | we
# City not found. Skipping...
# Processing Record 27 of Set 10 | elko
# Processing Record 28 of Set 10 | coutances
# Processing Record 29 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 10 | mnogovershinnyy
# Processing Record 31 of Set 10 | escanaba
# Processing Record 32 of Set 10 | nizhniy kuranakh
# Processing Record 33 of Set 10 | abu dhabi
# Processing Record 34 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 10 | berdyuzhye
# City not found. Skipping...
# Processing Record 36 of Set 10 | vilkaviskis
# Processing Record 37 of Set 10 | altamont
# Processing Record 38 of Set 10 | khanpur
# Processing Record 39 of Set 10 | maldonado
# Processing Record 40 of Set 10 | escarcega
# Processing Record 41 of Set 10 | krasnodon
# Processing Record 42 of Set 10 | jhabua
# Processing Record 43 of Set 10 | muros
# Processing Record 44 of Set 10 | liverpool
# Processing Record 45 of Set 10 | santa fe
# Processing Record 46 of Set 10 | san jeronimo
# Processing Record 47 of Set 10 | iqaluit
# Processing Record 48 of Set 10 | liberal
# Processing Record 49 of Set 10 | fairbanks
# Processing Record 0 of Set 11 | haverhill
# Processing Record 1 of Set 11 | clonakilty
# Processing Record 2 of Set 11 | ponta do sol
# Processing Record 3 of Set 11 | tautira
# Processing Record 4 of Set 11 | kavali
# Processing Record 5 of Set 11 | tagusao
# Processing Record 6 of Set 11 | daru
# Processing Record 7 of Set 11 | san cristobal
# Processing Record 8 of Set 11 | azrow
# City not found. Skipping...
# Processing Record 9 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 11 | mayo
# Processing Record 11 of Set 11 | opuwo
# Processing Record 12 of Set 11 | butembo
# Processing Record 13 of Set 11 | flinders
# Processing Record 14 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 15 of Set 11 | evanston
# Processing Record 16 of Set 11 | vila velha
# Processing Record 17 of Set 11 | hirara
# Processing Record 18 of Set 11 | turukhansk
# Processing Record 19 of Set 11 | mtambile
# Processing Record 20 of Set 11 | hongjiang
# Processing Record 21 of Set 11 | kontagora
# Processing Record 22 of Set 11 | buin
# Processing Record 23 of Set 11 | banda aceh
# Processing Record 24 of Set 11 | nizwa
# Processing Record 25 of Set 11 | mahibadhoo
# Processing Record 26 of Set 11 | sterling
# Processing Record 27 of Set 11 | jumla
# Processing Record 28 of Set 11 | cambridge
# Processing Record 29 of Set 11 | sakakah
# Processing Record 30 of Set 11 | san ramon
# Processing Record 31 of Set 11 | ronneby
# Processing Record 32 of Set 11 | hofn
# Processing Record 33 of Set 11 | zeya
# Processing Record 34 of Set 11 | raudeberg
# Processing Record 35 of Set 11 | channel-port aux basques
# Processing Record 36 of Set 11 | santa marta
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | rancho santa margarita
# Processing Record 39 of Set 11 | husavik
# Processing Record 40 of Set 11 | panjab
# Processing Record 41 of Set 11 | atlantic city
# Processing Record 42 of Set 11 | atchison
# Processing Record 43 of Set 11 | mali
# Processing Record 44 of Set 11 | westport
# Processing Record 45 of Set 11 | ivanjica
# Processing Record 46 of Set 11 | atar
# Processing Record 47 of Set 11 | namatanai
# Processing Record 48 of Set 11 | minab
# Processing Record 49 of Set 11 | quatre cocos
# Processing Record 0 of Set 12 | labuan
# Processing Record 1 of Set 12 | calvinia
# Processing Record 2 of Set 12 | moba
# Processing Record 3 of Set 12 | barcelona
# Processing Record 4 of Set 12 | airai
# Processing Record 5 of Set 12 | kanigoro
# Processing Record 6 of Set 12 | santa barbara
# Processing Record 7 of Set 12 | merauke
# Processing Record 8 of Set 12 | talavera de la reina
# Processing Record 9 of Set 12 | bombay
# Processing Record 10 of Set 12 | lai
# Processing Record 11 of Set 12 | puerto carreno
# Processing Record 12 of Set 12 | gurupi
# Processing Record 13 of Set 12 | viedma
# Processing Record 14 of Set 12 | obluche
# City not found. Skipping...
# Processing Record 15 of Set 12 | tashtagol
# Processing Record 16 of Set 12 | moerai
# Processing Record 17 of Set 12 | ambilobe
# Processing Record 18 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 19 of Set 12 | joensuu
# Processing Record 20 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 12 | aakirkeby
# City not found. Skipping...
# Processing Record 22 of Set 12 | porto novo
# Processing Record 23 of Set 12 | roma
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 12 | alice springs
# Processing Record 27 of Set 12 | carauari
# Processing Record 28 of Set 12 | noumea
# Processing Record 29 of Set 12 | santa helena de goias
# Processing Record 30 of Set 12 | faanui
# Processing Record 31 of Set 12 | dedovichi
# Processing Record 32 of Set 12 | montijo
# Processing Record 33 of Set 12 | avera
# Processing Record 34 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 35 of Set 12 | grindavik
# Processing Record 36 of Set 12 | turka
# Processing Record 37 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 12 | kyra
# Processing Record 39 of Set 12 | yar-sale
# Processing Record 40 of Set 12 | belaya gora
# Processing Record 41 of Set 12 | tuy hoa
# Processing Record 42 of Set 12 | russell
# Processing Record 43 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 12 | konyshevka
# Processing Record 45 of Set 12 | tessalit
# Processing Record 46 of Set 12 | miraflores
# Processing Record 47 of Set 12 | sioux lookout
# Processing Record 48 of Set 12 | areosa
# Processing Record 49 of Set 12 | graaff-reinet
# Processing Record 0 of Set 13 | mon
# Processing Record 1 of Set 13 | choix
# Processing Record 2 of Set 13 | podgornoye
# Processing Record 3 of Set 13 | vylgort
# City not found. Skipping...
# Processing Record 4 of Set 13 | newport
# Processing Record 5 of Set 13 | batemans bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          553
# Lat           553
# Lng           553
# Max Temp      553
# Humidity      553
# Cloudiness    553
# Wind Speed    553
# Country       553
# Date          553
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    sayyan  15.1718   44.3244     19.72        47          69        1.55
# 1  meulaboh   4.1363   96.1285     26.79        86          76        2.40
# 2  souillac -20.5167   57.5167     27.21        78          75        3.60
# 3    ekhabi  53.5102  142.9671     -3.28        91          20        6.23
# 4   rikitea -23.1203 -134.9692     26.23        87         100        6.21
#
#   Country        Date
# 0      YE  1682258483
# 1      ID  1682258484
# 2      MU  1682258486
# 3      RU  1682258487
# 4      PF  1682258488

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.tail(20)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 533            montijo  38.7067   -8.9739     24.21        62          40
# 534              avera  33.1940  -82.5271     19.19        45          28
# 535          grindavik  63.8424  -22.4338      6.97        70          75
# 536              turka  49.1541   23.0297     14.85        51          91
# 537               kyra  49.5776  111.9753      3.26        33         100
# 538           yar-sale  66.8333   70.8333      0.77        99         100
# 539        belaya gora  68.5333  146.4167     -7.56        94         100
# 540            tuy hoa  13.0833  109.3000     24.69        92           2
# 541            russell  32.3502  -85.1999     18.87        63           0
# 542         konyshevka  51.8418   35.2941     15.50        39          94
# 543           tessalit  20.1986    1.0114     35.27         8           7
# 544         miraflores  19.2167  -98.8083     18.90        60          98
# 545      sioux lookout  50.1001  -91.9170     -3.89        84         100
# 546             areosa  41.7178   -8.8571     16.74        89          52
# 547      graaff-reinet -32.2522   24.5308     27.18        36           0
# 548                mon  26.7500   95.1000     16.76        98         100
# 549              choix  26.7092 -108.3219     22.30        17           1
# 550         podgornoye  51.7350   39.1496     17.12        39           0
# 551            newport  51.5877   -2.9984     13.16        75         100
# 552       batemans bay -35.7167  150.1833     17.28        82          95
#
#          Wind Speed Country        Date
# City_ID
# 533            2.06      PT  1682258978
# 534            0.93      US  1682259221
# 535            4.63      IS  1682259223
# 536            1.70      UA  1682259224
# 537            2.23      RU  1682259227
# 538            8.55      RU  1682259228
# 539            2.30      RU  1682259229
# 540            1.85      VN  1682259230
# 541            0.00      US  1682259232
# 542            1.03      RU  1682259234
# 543            3.55      ML  1682259235
# 544            1.46      MX  1682259237
# 545            2.22      CA  1682259238
# 546            5.10      PT  1682259239
# 547            1.77      ZA  1682259241
# 548            1.14      IN  1682259242
# 549            1.60      MX  1682259243
# 550            2.00      RU  1682259245
# 551            3.39      GB  1682259247
# 552            2.60      AU  1682259031

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values =city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)



# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature 2023-04-21")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid()
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values =city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity 2023-04-21")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values =city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness 2023-04-21")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values =city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed 2023-04-21")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           sayyan  15.1718   44.3244     19.72        47          69
# 1         meulaboh   4.1363   96.1285     26.79        86          76
# 3           ekhabi  53.5102  142.9671     -3.28        91          20
# 8         pasighat  28.0667   95.3333     20.98        81         100
# 9        nantucket  41.2835  -70.0995     11.06        86          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.55      YE  1682258483
# 1              2.40      ID  1682258484
# 3              6.23      RU  1682258487
# 8              2.92      IN  1682258493
# 9              9.77      US  1682258211

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] <0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2            souillac -20.5167   57.5167     27.21        78          75
# 4             rikitea -23.1203 -134.9692     26.23        87         100
# 5        punta arenas -53.1500  -70.9167      5.06        81           0
# 6              neiafu -18.6500 -173.9833     21.38        94          20
# 7          santa cruz -17.8000  -63.1667     22.65        60          98
#
#          Wind Speed Country        Date
# City_ID
# 2              3.60      MU  1682258486
# 4              6.21      PF  1682258488
# 5              0.00      CL  1682258399
# 6              0.00      TO  1682258491
# 7              3.16      BO  1682258410

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(0.8,0.8),fontsize=15,color="red")
Latitude = northern_hemi_df["Lat"]
Temperature = northern_hemi_df["Max Temp"]
#correlation = st.pearsonr(Latitude,Temperature)
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is -0.8503073527768139

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(-28,10),fontsize=15,color="red")
Latitude = southern_hemi_df["Lat"]
Temperature = southern_hemi_df["Max Temp"]
#correlation = st.pearsonr(Latitude,Temperature)
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.7338058574346914

# %%
# There is a strong relationship between latitude and Max Temperature.  
#The further away from the equator you go, whether that be north or south the lower the temperature is

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(9,9),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.15999359262151927

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(-57,20),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.20074513768979124

# %%
#There is virtually no relationship between humidity and latitude,

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(3.8,30),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.13374908055114765

# %%
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(-45,22),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.3019532083544461

# %%
#No major relationshp between distance from the equator and cloudiness
# r values less than 0.25, -0.25

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
regress_values = northern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(northern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(3,9),fontsize=15,color="red")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is 0.20300714419117208

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
(slope, intercept, rvalue, pvalue, sterr) = linregress(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
regress_values = southern_hemi_df["Lat"] * slope + intercept
line_eq = "y =" +str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_hemi_df["Lat"],regress_values,color = "red")                                                                                                         
plt.annotate(line_eq,(-25,9.5),fontsize=15,color="red")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
print(f"The r value is {rvalue}")
plt.show()
# Out:
# The r value is -0.09984028819230842

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
#No major relationshp between distance from the equator and wind speed
# r values less than 0.25, -0.25
